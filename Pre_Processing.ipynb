# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\venka\\Desktop'

# %%
import nltk
import re
import numpy as np # linear algebra
import pandas as pd # data processing
import random
import matplotlib.pyplot as plt

from bs4 import BeautifulSoup
from nltk.corpus import stopwords
from string import punctuation
from nltk.stem import SnowballStemmer
stemmer=SnowballStemmer('english')

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

from nltk.tokenize import word_tokenize


#import pandas_profiling

# %matplotlib inline

# %%
data=pd.read_csv("reviews.csv")

# %%
data.head()
# Out:
#                                         Product Name Brand Name   Price  \
# 0  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 1  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 2  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 3  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 4  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
#
#    Rating                                            Reviews  Review Votes
# 0       5  I feel so LUCKY to have found this used (phone...           1.0
# 1       4  nice phone, nice up grade from my pantach revu...           0.0
# 2       5                                       Very pleased           0.0
# 3       4  It works good but it goes slow sometimes but i...           0.0
# 4       4  Great phone to replace my lost phone. The only...           0.0

# %%
df=data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413840 entries, 0 to 413839
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Product Name  413840 non-null  object
#  1   Brand Name    348669 non-null  object
#  2   Price         407907 non-null  float64
#  3   Rating        413840 non-null  int64
#  4   Reviews       413778 non-null  object
#  5   Review Votes  401544 non-null  float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 18.9+ MB

# %%
df.describe()
# Out:
#                Price         Rating   Review Votes
# count  407907.000000  413840.000000  401544.000000
# mean      226.867155       3.819578       1.507237
# std       273.006259       1.548216       9.163853
# min         1.730000       1.000000       0.000000
# 25%        79.990000       3.000000       0.000000
# 50%       144.710000       5.000000       0.000000
# 75%       269.990000       5.000000       1.000000
# max      2598.000000       5.000000     645.000000

# %%
df=df[['Reviews','Rating']]
df.head()
# Out:
#                                              Reviews  Rating
# 0  I feel so LUCKY to have found this used (phone...       5
# 1  nice phone, nice up grade from my pantach revu...       4
# 2                                       Very pleased       5
# 3  It works good but it goes slow sometimes but i...       4
# 4  Great phone to replace my lost phone. The only...       4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413840 entries, 0 to 413839
# Data columns (total 2 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   Reviews  413778 non-null  object
#  1   Rating   413840 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 6.3+ MB

# %%
df=df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 413778 entries, 0 to 413839
# Data columns (total 2 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   Reviews  413778 non-null  object
#  1   Rating   413778 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 9.5+ MB

# %%
df=df[df['Rating']!=3]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 382015 entries, 0 to 413839
# Data columns (total 2 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   Reviews  382015 non-null  object
#  1   Rating   382015 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 8.7+ MB

# %%
df=df.reset_index(drop=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 382015 entries, 0 to 382014
# Data columns (total 2 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   Reviews  382015 non-null  object
#  1   Rating   382015 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 5.8+ MB

# %%
df['sentiment']=np.where(df['Rating'] > 3, 1, 0)
df.head()
# Out:
#                                              Reviews  Rating  sentiment
# 0  I feel so LUCKY to have found this used (phone...       5          1
# 1  nice phone, nice up grade from my pantach revu...       4          1
# 2                                       Very pleased       5          1
# 3  It works good but it goes slow sometimes but i...       4          1
# 4  Great phone to replace my lost phone. The only...       4          1

# %%
df.tail()
# Out:
#                                                   Reviews  Rating  sentiment
# 382010  good rugged phone that has a long-lasting batt...       4          1
# 382011                                          used hard       1          0
# 382012                     another great deal great price       5          1
# 382013        Passes every drop test onto porcelain tile!       5          1
# 382014  Only downside is that apparently Verizon no lo...       4          1

# %%
df
# Out:
#                                                   Reviews  Rating  sentiment
# 0       I feel so LUCKY to have found this used (phone...       5          1
# 1       nice phone, nice up grade from my pantach revu...       4          1
# 2                                            Very pleased       5          1
# 3       It works good but it goes slow sometimes but i...       4          1
# 4       Great phone to replace my lost phone. The only...       4          1
# ...                                                   ...     ...        ...
# 382010  good rugged phone that has a long-lasting batt...       4          1
# 382011                                          used hard       1          0
# 382012                     another great deal great price       5          1
# 382013        Passes every drop test onto porcelain tile!       5          1
# 382014  Only downside is that apparently Verizon no lo...       4          1
#
# [382015 rows x 3 columns]

# %%
df
# Out:
#                                                   Reviews  Rating  sentiment
# 0       I feel so LUCKY to have found this used (phone...       5          1
# 1       nice phone, nice up grade from my pantach revu...       4          1
# 2                                            Very pleased       5          1
# 3       It works good but it goes slow sometimes but i...       4          1
# 4       Great phone to replace my lost phone. The only...       4          1
# ...                                                   ...     ...        ...
# 382010  good rugged phone that has a long-lasting batt...       4          1
# 382011                                          used hard       1          0
# 382012                     another great deal great price       5          1
# 382013        Passes every drop test onto porcelain tile!       5          1
# 382014  Only downside is that apparently Verizon no lo...       4          1
#
# [382015 rows x 3 columns]

# %%
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()
# Out:
# [nltk_data] Error loading stopwords: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>

# %%
data=[]
for i in range(0,1000):
    review=df["Reviews"][i]
    review=re.sub('[^a-zA-Z]',' ',review)
    review=review.lower()
    review=review.split()
    review=[ps.stem(word) for word in review if not word in set(stopwords.words('english'))]
    review=' '.join(review)
    data.append(review)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-90d228f0a361> in <module>
#       1 data=[]
#       2 for i in range(0,1000):
# ----> 3     review=df["Reviews"][i]
#       4     review=re.sub('[^a-zA-Z]',' ',review)
#       5     review=review.lower()
#
# NameError: name 'df' is not defined

# %%
data
# Out:
# ['feel lucki found use phone us use hard phone line someon upgrad sold one son like old one final fell apart year want upgrad thank seller realli appreci honesti said use phone recommend seller highli would',
#  'nice phone nice grade pantach revu clean set easi set never android phone fantast say least perfect size surf social media great phone samsung',
#  'pleas',
#  'work good goe slow sometim good phone love',
#  'great phone replac lost phone thing volum button work still go set adjust job elig upgrad phone thaank',
#  'alreadi phone problem know state use dang state charg wish would read comment would purchas item crack side damag good tri charg anoth way work request money back get money back sign unhappi custom',
#  'charg port loos got solder need new batteri well later includ cost purchas usabl phone phone sold state',
#  'phone look good stay charg buy new batteri still stay charg long trash money lost never buy person',
#  'origin use samsung galaxi sprint want return back samsung epic g sprint realli miss keyboard realli like smaller compact size phone still need basic function smart phone e check e mail get direct text messag phone power newer cell phone awar applic instal slower phone run like freez time time camera work great video great well even web brows decent give need also notic batteri life last littl bit longer charg phone much quicker galaxi',
#  'great product came two day order one littl blemish side care long phone fullli function recommend product anyon read',
#  'guy best littl situat item quickli fix issu pleas definit buy anoth phon need one',
#  'realli disappoint phone servic phone went week ago instead handl issu first surfac told stick phone dollar servic use still receiv mail label return item first purchas amazon rush use smartphon busi anytim soon thought get deal seem like one luck',
#  'order phone replac model contract expir get new one seller confirm said deliveri could take day seller sent phone within hour receiv order phone next day phone look better describ abl transfer data old one new one problem highli recommend seller',
#  'phone love work got phone one thing sd card slot open tri access file manag even show comput card fine abl open anoth phone tri troubl shoot',
#  'abl get phone previous own keyboard touch screen best phone love still clean devic servic provid well worth',
#  'brought phone replac daughter hard cell phone must say great purchas phone work wonder thank',
#  'love phone everyth need work great purchas four phone seller ship amazon warehous problem phone come micro sd card use camera got card problem get activ sprint',
#  'batteri old use bare hold charg otherwis issu phone',
#  'pro beauti screen capabl run chrome take good pictur keyboard comfi fit pocket fit hand play realli good video gamescon bluetooth came late run fast realli quick doesnt play p video would still recommend like talk text lot like watch lot movi',
#  'purchas phone decemb christma present son call sprint activ phone find esn clear told come store upon research phone clear reach compani inform esn clean told send phone back would send anoth phone ask repres provid esn could call make sure clear told phone avail guarante would clear known someth wrong receiv second phone turn clear esn repres sprint inform seller phone awar esn clear send anoth phone back ask refund phone ship sinc sent two phone clear esn receiv refund phone yet see refund ship suggest buy anyth',
#  'phone good littl slow phone old great phone temporari right thank great deal',
#  'phone speaker littl low overal happi phone would purchas anoth cell phone chubbietech satisfi',
#  'phone great good condit daughter happi andriod user',
#  'phone work great problem',
#  'good condit work good',
#  'good phone great screen resolut storag low need sd card anyth may clear esn expect use thing like freedompop',
#  'describ fast ship',
#  'perfect everi way',
#  'one phone bad charger port want send back',
#  'got phone great phone easi use',
#  'phone great gotten old time replac great last',
#  'phone came great condit great price bring back great memori own phone',
#  'met expect complain great price',
#  'phone work plan use whatsapp anyway oh problem chang idiom',
#  'excel product perfect condit',
#  'excel',
#  'excelent',
#  'excelent',
#  'like phone bought mom love',
#  'came arabian keyboard',
#  'love',
#  'practic user friendli phone satisfi',
#  'sharp classi phone',
#  'good',
#  'gooddd',
#  'ship quickli exactli expect',
#  'work wonder price',
#  'bought altern smart phone data plan use go phone pay go plan phone function great radio music player good sound qualiti smart phone type featur easier faster use smart phone use softwar glitch document nokia support site prove easili fix even though mani nokia base featur longer support microsoft still use featur need access web directli via wifi connect data want pay privileg launch site applic although new nokia browser pretti spartan appear fast run good stabil big guy land larg even size find full qwerti keyboard pretti easi use like programm hot key screen shortcut keep launch item requir data connect accid back light thorough even rais button tactil posit click respons phone quirk airplan mode far tell flight profil seem abl set broadcast receiv function turn main navig button mous littl small alway respond expect might though would recommend phone vendor highli want featur smart phone need gp big data bill everi month bunch thing need want keep life run smoothli',
#  'muy buen producto',
#  'phone trap want simpl phone get old school flip phone want someth also work get blackberri somth new even middl two anoth dimens noth frustrat phone',
#  'excel',
#  'friend mention phone worth said thank lot friend',
#  'use unlock gsm nokia asha philippin recent jan feb excel problem function bought p sim card airport presto work pass brother instant came back us visit philippin soon easi use use smart phone w touch screen surpris work w easili read instruct oper buy anoth one like definit upgrad version nokia unlock gsm phone',
#  'excelent',
#  'excel phone youngest son walk reason option qualiti first',
#  'excelent',
#  'solid phone',
#  'good choic',
#  'perfect practic easi handl good resolut well pack',
#  'excel product right recommend',
#  'excelent',
#  'excelent',
#  'nokia brand use telephon good price excel team gift daughter like easi use afford price recommend',
#  'first let say nokia user sinc first cell phone age ten year ago cours one year ventur samsung land phone die back nokia went alway enjoy nokia phone second look qwerti phone internet video mp play capabl asha fit strong build drop numer time phone still intact like keyboard fan touchscreen get asha far sound think depend headphon earbud produc loud decibel made listen experi mediocr bought bud db loud sound much better nokia xpress bit sucki download opera browser phone work slightli better internet experi pretti easi get video game sn even pc reason use phone wish built antenna could listen radio without rd earbud realli great phone want move blackberri want pay much nokia asha great phone start edit octob found gino cm section telescop stainless steel fm radio antenna mm plug use play radio speaker realli enjoy phone sit outsid friend desk',
#  'nokia asha unlock gsm phone mp camera video qwertydependabletradit nokia menu snot complic like smart phone durableeasi use straighttalk internet wifi bluetooth',
#  'solidli built unlock phone updat popular nokia c run softwar good bad good recept nice audio g support band mobil hspa refarm pc band band keyboard pretti good firm nokia qwerti phone e g e compar c keyboard one obvious world market sinc ad european char symbol keypad wi fi work fine opera mini instal run without problem good way go bit web surf tri e mail social client text messag set normal box convers mode ovi store app seem work well coupl featur found appeal abil backup phone memori sd card abil lock keypad passcod either manual automat set time batteri fairli good size bl j function key pad key assign user defin short cut opinion worthi updat g c quit leagu expens e multi task softwar price around unlock featur gsm g phone well worth consid long one know one get non smart phone app limit',
#  'hola compramo do tel fono vienieron totalent diferent uno vino con la bater da ada se descarga de inmediato el otro tel fono vino sin la tarjeta de memoria lo teclado cargador son muy distinto mi yo no sentimo enga ada defraudada',
#  'cellphon easi use complet app import contact peopl incorpor use wi fi connect satisfi purchas simpl phone complet import',
#  'gracia llego el procto que compr llevo en el momento indicado en un buen envalaj lo recomiendo sastifactoriament',
#  'freez alot bought primarili play back music instead bb great phone sm ring realli loud bodi strong neat',
#  'key littl hard hit expect spanish keyboard overal good phone',
#  'prefac would consid smartphon unit state noth par android iphon window phone basic featur phone also although say us warranti warranti materi came referenc latin american countri sure realli cover us warranti return amazon return window issu phone review pro phone great keyboard familiar e seri phone type keyboard interfac sort modifi symbian like lot way style hardwar attract gray nice color camera pretti decent consid megapixel e mail adequ con start small issu work big problem ultim made decid return phone onboard social network app fulli function updat facebook twitter statu rest ovi store gener poor app store phone abl use mani even old facebook app use old e use call snaptu facebook sinc renam facebook everyon incompat phone better app ovi store browser mediocr bare passabl also gp phone nokia ovi map incompat bad alway nokia strength immedi elimin phone smart phone said bought phone wife realli need phone text call could overlook thing problem could overlook shabbi flimsi piec metal suppos hold place standard sim card littl piec metal bare attach phone would lock place hold sim card sim card would intermitt get lose insid phone constantli lose signal would take batteri adjust sim card would work littl ultim repeat process way frustrat worth bad basic phone call text e mail occasion updat facebook twitter statu phone lot potenti becuas problem sim card holder howev essenti unus use nokia phone year use lumia person realli surpris nokia would sloppi job someth import part hold sim card place wast',
#  'receiv phone day ago put consum cellular sim card readi go phone seem nice even though come close discov thing larg number ring tone built',
#  'bought phone christma present want someth bit advanc nokia c purchas amazon want go way smartphon word good featur phone smartphon featur without touch screen red howev favorit color went white one c silver find silver asha amazon week work great best wi fi featur give access web without purchas data plan may want access person email go facebook great calendar alarm clock text messag camera miss receiv call featur c make keeper littl bigger wider screen big fit pocket purs use nokia charger c await arriv purpl phone skin right nokia phone sinc never let get better',
#  'phone pretti good use lycamobil plan thing awkward bottom row letter compar phone devic use blackberri tri type nokia alway mistyp ms ns especti shift key need hit insert punctuat',
#  'love everyth also look like touch phone make stylish yet classic',
#  'solut want look econom sophist price good choic product receiv recommend',
#  'phone excel phone great price impress featur phone would recommend anyon',
#  'good phone although seem small screen howev capabl perform basic function call messag web brows social network also wi fi capabl',
#  'long time user iphon final got sick sold want simpl phone go fit bill well text interfac nice intuit batteri life stellar connect internet fine check email case emerg look direct etc basic everyth abl smartphon without bell whistl physic keyboard quit nice os seem stabl snappi thing like calendar todo memo etc backup snap insert sd card go set back itun want add music podcast plug comput copi past sd card done would buy phone definit broke lost',
#  'phone like nokia featur phone great valu durabl last phone buy one nokia c also great phone last year probabl would kept go accident jump pool pocket p phone basic updat c sleek small full qwerti keyboard wi fi internet brows best phone get look function want throw hundr dollar smartphon data plan buyer awar smartphon look anyth like smartphon disappoint look toy take pocket everi coupl minut tinker around disappoint ye internet browser work well screen quit small good recreat brows use look thing work fine also social network app use know well work prioriti phone probabl best choic goe camera use speak qualiti camera import best choic potenti neg see phone key realli pretti small issu person someon big hand see could annoy bought phone advantag own smartphon longer batteri life higher durabl lower cost still good accomplish need look thing nokia definit best way go',
#  'love',
#  'sorri took long repli review purchas month phone clone phone hong kong qualiti fair symbol match phone work think amazon boycott seller',
#  'bought gift mum love strong durabl phone good recept function well',
#  'incred phone splaniish languag dont understand intern version lost money',
#  'bad',
#  'good',
#  'batteri die less hour',
#  'excel product',
#  'well',
#  'cannot connect gsm network',
#  'cell phone exceed expect user friendli everyth work like said would price amazingli cheap featur enorm help',
#  'pro work fine easi use heavi con app android iphon bb',
#  'went lot review differ phone buy found phone pretti good problem far',
#  'excelent',
#  'excelent',
#  'phone work great look great ship quiet quickli issu european charger purchas micro usb usb cabl charg phone would download updat system way',
#  'ver good',
#  'excel phone special function commun social network excel oper recommend excel product',
#  'buy feel like pretend toy hand want kid ok',
#  'excel phone adult recommend whatsapp internet app radio keyboard qwerti easi use display big visualis funni',
#  'enjoy nokia c phone year tire need updat asha phone symbian simpl good much higher qualiti set hardwar screen sharper processor faster phone take nice clear pictur pretti much good enough ring alert tone discreet profession internet mail stuff actual useabl mobil g network requir littl data stay connect minum plan strang cannot wifi yet receiv signal insist use network data noth probabl set menu toggl right set anyway want phone text easili day batteri conveni useabl featur yet crack open crack pipe internet constanli asha style may get anoth one two futur bet end run type practic phone',
#  'got phone work took verizon store batteri work even charg hr verizon put anoth use batteri phone start work',
#  'like',
#  'great arriv quickli',
#  'phone work great may get sum card adapt make micro sim cat work',
#  'avianna llc incred seller phone take get place howev phone work provid andrew stay phone tech support servic provid hr tri get phone work work immedi sent replac phone use recept feedback constantli contact problem aris product describ use sprint unlock blackberri bold believ servic provid problem',
#  'exactli expect thank',
#  'got faster expect need job thank lot',
#  'exelent',
#  'phone work great price although got up up guy drop screen door big door',
#  'keep mind sub phone gener advertis cheapest quad core phone landvo l turn good phone exceed expect research landvo seem new compani l first model releas march took risk although less huge risk buy april review avail main thing look power inexpens phone price point batteri life also major factor purchas phone basi phone price rang time quadcor processor also sport mah batteri largest batteri price point avail model lot thing immedi like phone despit low resolut lack ip screen pretti crisp view angl decent batteri life also good averag two day averag use full charg one day heavi use would usual put around rang still bad also almost shock build qualiti phone heavier name brand competit size class weighti solid feel side metal volum rocker power button creak everyth fit togeth tightli fit finish top notch believ screen plastic glass howev pro con plastic screen suscept scratch howev mean never worri crack screen drop phone phone came screen protector prefit phone addit one box includ silicon case rel simpl also nice touch especi owe fact name brand phone unlik third parti support case howev would recommend phone anyon time perform lacklust quadcor soc quit snappi howev small mb ram suffer android wari purchas phone less gb ram regret point would freez stutter even simplest task hammer text put forth best effort streamlin system much possibl keep run smoothli fact enough ram power android comfort readi ditch phone someth new complet chang tune howev hesit recommend phone heartbeat surprisingli landvo support releas offici kitkat rom phone tech savvi boon kitkat actual streamlin googl devic mb ram run comfort bit resourc hog point figur noth lose plan dump phone anyway needless say flash kitkat made world differ perform liter night day upgrad liter got rid lag experienc phone quit fast would argu faster sero pro tablet run old vener tegra processor demand app load quickli without stutter anim smooth everyth becom joy use phone look ridicul cheap fast android phone good batteri life good build qualiti one look hand go compet totl phone measli expect get perfectli usabl phone almost throw away price notic vendor sell l android alreadi instal look like new stock phone upgrad tech savvi comfort flash phone make sure purchas one alreadi instal love',
#  'good product recomend need fast good look good thank',
#  'autist son glori lol thank',
#  'around good phone glitchi laggi fee problem storag small gb camera poor qualiti pretti certain buy galaxi camera instal phone around pretti great phone',
#  'problem take phone straight talk phone came week thing like camera horribl tri get take pictur pictur clear',
#  'deliveri fast overal qualiti phone like price cheap good qualiti camera one featur use also durabl screen damag inch drop howev suppos get pay month will buy real phone lose terribl one',
#  'perfect',
#  'work ok awhil everi time tap back shut',
#  'great phone sone happi need get extra micro sd card storag',
#  'good excel',
#  'first got phone poor camera one day hit phone pencil turn immedi like phone whatsoev would recommend get phone especi like take lot pictur use lot app storag also poor',
#  'cheap fast',
#  'good cell',
#  'respons seller excel product',
#  'muy bueno',
#  'fino fino',
#  'exelent equipo en lenguaj criollo son una verdadera nave',
#  'good',
#  'great price hate chang lock screen wantand default wallpap lockscreen',
#  'got new phone love phone android small limit would let set sd card want may upgrad new android heard work better figur use straight talk problem set straight talk apn set far want find better protect case found like hope make one phone',
#  'like fm radio featur charg cradl switch back lg flip phone cost less best buyrecept weak signal area good lg phone mobil networkbacklight uneven keypad number realli bright phone user manual small phone design older peopl manual size phone fit small box ship manual explain use button clear concis way get alarm repeat daili turn alarm would cancel alarm next day',
#  'bouht phone year old mother macular degener love easi see big number dial',
#  'like ad love',
#  'famili member zero interest learn anyth tech year ago gave old mobil pre paid flip phone kept year backup phone perfect want learn anyth els problem phone button small get hard order put sim away went love lot extra stuff ever decid want learn love much larger button dead simpl use want',
#  'good qualiti phone',
#  'work well mobil mobil close tower non mobil phone',
#  'screen size good easi read sound could littl louder okay set littl cryptic get job done extra key stoke realli need care way setup text hit button twice get capit letter hit turn capit brand phone automat capit first letter period one still good phone though worth money',
#  'like th cellphon dad less year dad alway type heavi labour work process alway end destroy process well first impress reciev cellphon mail keypad realli like number huge also display quit clear crispi simpl understand problem adjust new devic fm radio need headphon work camera ok best plausibl sd slot media cannot play music video file dont show tri search folder memori like led light alert notif plu rington pretti loud good pick age parent',
#  'realli great phone visual impair problem get anoth one partner',
#  'complic expect terribl recept hard mom use frustrat',
#  'phone recept poor incom call',
#  'nice phone easi read screen senior tech learn curv steep support jethro howev made easi knowledg easi understand patient will help would recommend phone so button good featur limit use telephon much less expens tool life line',
#  'sleek design easi use make phone realli good larg text plu',
#  'husband love simpl use larg number simpler better',
#  'even instruct book better ever senior need big print phone websit page clearli tell us senior take instruct go place especi travel comput readili hand rememb laptop gener get tablet often small otherwis far great love name ask brother jethro leav',
#  'phone purchas father realli like featur price excel deal took exactli month get everyth work phone issu phone first unlock phone consum cellular manual came phone good thing manual match phone receiv lot help jethro jeffrey jethro godsend extrem help alway cheer voic call sent pictur etc whatev took help issu even though obviou problem jethro end realli like phone star jeffrey hope jethro realiz great employe',
#  'work good g simpl use frill',
#  'simpl sleek minimalist accept sim perfect back phone nice matt finish pretti emerald green notif light cool alarm rington could improv limit space messag stop accept txt even ad sd card help program util messag camera wors secur footag even bother menu structur intuit',
#  'sound like water shut call',
#  'contact jethro custom servic coupl key stick speak rep notic break much told phone g like work well area kind enough send g phone model sc one seem work fine far must say best custom servic respons solv issu',
#  'new edit jethro sc v flip quad band unlock gsm senior kid cell phone so emerg button larg lcd larg keypad nice phone easi oper cost friendli also light easili portabl use micro sim save music photo',
#  'everyth great hard time get old sim card work verizon hook',
#  'bought phone supposedli abl work straighttalk tracfon put tracfon sim card board bought buck straighttalk minut card discov compat straighttalk ther local walli world want least buck sim card kit work supposedli daughter work hour call everi avail number good expert today high tech cheaper tracfon card avail ask daughter take anoth tri time job famili take care anoth point way manual use download pdf print regular page otherwis reader strength magnifi glass recommend anyon particularli elderli peopl readi turn',
#  'met expect easi use gave gift veto elderli rel love',
#  'bought phone year old aunt seem easi use would certainli recommend purchas anoth brand senior phone price last week due qualiti phone screen',
#  'receiv product',
#  'good phone elderli peopl',
#  'bought mom love',
#  'search unlock flip phone old mobil longer work hous look good capabl second minisim need simplic husband bare answer flip phone let alon use desir buy mini sim believ badli describ manual bad english seem differ phone',
#  'unhappi purchas first paid ship receiv found staight talk would longer work att cell phone carrier area abl send back pay postag happi ken',
#  'comput programm admit never made transit smartphon mainli sit comput everyday anyway need access smartphon app use laptop besid screen tini farsight mean use smartphon go carri even item read glass adventur type bike motorcycl hang glide scuba etc could find need assist one riski adventur live alon might need get help car breakdown home injuri situat bought one pre paid cell thought go problem solv kept pocket dial see screen either wors thing batteri would go dead everi day sinc never use cell phone except emerg would alway alway forget charg prepaid work emerg phone jethro solv problem big screen clamshel inexpens pre paid soooo much use clamshel get pocket dial big screen carri read glass around actual use littl take todo note use calcul well great fm radio flashlight batteri last week standbi mode honestli use yet real emerg phone call yet place sever test call work great jethro took pre paid mobil sim problem run minut need cellphon throw backpack glove box case emerg plu inexpens break lose biggi',
#  'fast ship accur descript',
#  'phone unabl maintain signal week usag tmobil network hope defect product',
#  'great phone',
#  'shortli return window close stop take charg turn',
#  'stop work month happi phone',
#  'defect product place mobil sim card phone read recommend purchas phone',
#  'sound qualiti poor speaker phone',
#  'great phone',
#  'excelent',
#  'phone met expect dad love enjoy',
#  'bought elderli grandfath vocal everyth get whether like like phone loud simpl need glass use abl sync',
#  'need older rel',
#  'gift grandma south america love thank',
#  'speaker garbag tell time militari time',
#  'bought phone elderli parent put sim card phone jethro work problem drop call would receiv make phone call phone would hang person line ask refund carrier phone bar phone call took place',
#  'great simpl phone get harder harder find want smartphon need phone elderli famili member someon tech savvi great littl phone gave four star though carrier recogn signatur phone wound buy friendli phone phone work bill system would automat charg smartphon extra bill sinc recogn signatur give militari reus',
#  'granni use phone abl use lock phone function without lock phone call peopl phone pocket lock easier phone would great',
#  'good sound easili use senior end button also turn button elderli mom keep turn phone find anoth one would purchas purchas deliveri schedul',
#  'realli surpris phone fm radio flashlight so featur nice well mom',
#  'nice big number everywher simpl',
#  'order phone would work call compani told due lack tower found odd sinc cell',
#  'good hope phone senior reminisc cordless hous phone make easi use year old button light bright rington volum adjust max loud enough anyon hear problem though surprisingli call volum adjust though louder previou verizon flip phone max volum set cricket servic phone take mini sim card micro someon els state buy anoth sim card micro order small mini sim origin larg card live us know peopl claim phone work us paid ish phone would paid design function side note concern grandmoth would alway accident hit so button phone disabl set',
#  'good',
#  'thank',
#  'easi use mother use well',
#  'sim card provid would work phone return phone',
#  'purchas phone parent difficulti small button phone thank size button display squint also love key rais menu layout also simpl use programm number make easi call frequent use number ringer volum good would buy',
#  'littl bit effort abl familiar phone use becam intuit came nice easi read booklet purchas check see web site insert sim card charg batteri took coupl hour sever problem first first cell phone much experi mistakenli set languag portugues figur luckili sever onlin tutori web site restor phone factori set english abl figur phone easili one thing figur use militari time pm equal set time pm set happi phone hear impair abl hear basic ring loud put pocket face keypad leg speaker come back even louder thing set tabl put face ring loud clear question use lanyard e mail jethro compani got right back confirm small hole upper left side could accommod lanyard remov back feed lanyard hole loop around replac back custom servic nice answer question easi understand manner phone lock pocket wont random dial need press asterisk screen say phone unlock dial phone alway accept call without turn exactli simpl phone look return sever work went model use consum cellular less expens aarp discount get hour talk per month',
#  'great simpl use phone mother big button easi see use use one arm charg cradl great benefit easi setup good clariti get good signal',
#  'bought mom late highest rate senior phone stop work hate phone confus oper menu function took chanc one despit complaint read review problem address correct longer difficult lock unlock key press lower left button coupl second word lock come assum sinc say spanish set mom phone spanish second way direct key need tri sinc mom got right away definit good technolog anoth complaint clock set militari hr time well choos set hr phone easi set relief compar previou phone let face non senior probabl set sometim effort simplifi phone take away button make harder navig phone light weight ringer loud enough like cradl easier senior beat price work well sim card neg side agre one complaint loud enough turn volum way afraid mom would abl hear caller agre give chanc may exchang sinc hear great back cover thin plastic afraid break remov wish alarm come senior phone slim pick one half price old one come close meet requir sinc senior hard hear realli need make louder',
#  'return product volum absolut abysm even maximum audibl bought elderli mother way abl hear anyth phone market elderli disgrac',
#  'simpl use seem get tiem updat',
#  'perfect great inexpens phone senior bright larg backlit number clear control larg number button light weight flash light gsm paid almost want one breath fresh air smart phone good batteri life realli luck choos might buy anoth one backup father tend misplac thing use giv mobil unlimit talk text mb data month contract',
#  'good phone mom big number howev set somewhat confus',
#  'lock accident use screen small read text messag easi use elderli person',
#  'bought phone grandma make receiv call tri manual select network also factori reset noth happen',
#  'good phone emerg number nice big easi use thank much',
#  'work iwirless',
#  'cyril surpriz',
#  'bought phone year old mother hear impair could hear well',
#  'arriv phone charg frustrat',
#  'look good advertis instruct easi follow key quit larg fairli easi see',
#  'dad love work great confus bell whistl',
#  'bad week bought could turn offnot worth hassl buy',
#  'grandma love could bigger screen rington',
#  'look',
#  'mom like kind chang taken time effort get embrac versu old flip phone',
#  'pro cradl nice lack camera cheaper snapfoncon recept terribl mobil phone work insid hous except one appar g phase expect recept get wors time time date set automat serious year unlik everi phone button directli screen actual navig button speed dial probabl problem someon first phone drove nut fcc id phone might illeg use us poor manufactur qualiti batteri hard insert remov batteri slightli big part suppos fit voic mail number program similar time date everi phone ever pick set network automat review mention hangup button press longer second phone power easi accident',
#  'stop work month use',
#  'placement button particular made confus elderli father use tri numer time get phone turn make simpl call could get work longer charg come week fortun cost much wast money',
#  'bought phone simpl option year old father like big button charg cradl phone feel cheap afraid break plastic piec pull cover get batteri sim card nstall differ sim card cricket wireless network store could get connect know sure someth broken phone incompat review say connect lead think someth wrong phone phone go back go tri anoth brand',
#  'give star know durabl everyth els perfect say call qualiti good so speed dial direct dial work great qualiti phone good dock station issu issu direct charg still rate star everyth els perfect',
#  'real nice simpl phone grandma',
#  'basic featur necessari senior',
#  'great phone elderli familiar w cell phone number larg easier see',
#  'work',
#  'love',
#  'love simpl handset limit number featur find get troubl',
#  'phone difficult unlock unlock phone need press unlock key time first press wake phone second press result messag say press unlock key unlock third press unlock phone easier method unlock keyboard without disabl lock altogeth buy phone someon elderli technolog issu may lot difficulti use phone three unlock press done quick enough unlock sequenc start unlock key press time phone lock instead unlock difficult explain someon dexter technolog issu never heard phone difficult unlock hard believ easier method unlock phone howev call custom support confirm phone take unlock press unlock phone altern disabl lock featur plu side so key work well requir one unlock key so key program send text messag call anoth thing note titl phone indic extra today howev rais price yesterday save hate compani rais price tell go save paid black friday price lower normal price',
#  'wish ring louder still heard ok hard hear like everyth louder easi work like lot button push accident might buy friend wonder compat verizon one problem set book say go set tell get set go left utton key push say phone book keep push arrow lead set unlock phone set ring',
#  'review grandmoth bill realiz pay month jitterbug phone unlimit talk use minut month text never sent one bought phone add contract line plan month gave work great',
#  'sim card provid would work phone return phone',
#  'purchas phone parent difficulti small button phone thank size button display squint also love key rais menu layout also simpl use programm number make easi call frequent use number ringer volum good would buy',
#  'great phone',
#  'excelent',
#  'phone met expect dad love enjoy',
#  'bought elderli grandfath vocal everyth get whether like like phone loud simpl need glass use abl sync',
#  'need older rel',
#  'gift grandma south america love thank',
#  'speaker garbag tell time militari time',
#  'bought phone elderli parent put sim card phone jethro work problem drop call would receiv make phone call phone would hang person line ask refund carrier phone bar phone call took place',
#  'great simpl phone get harder harder find want smartphon need phone elderli famili member someon tech savvi great littl phone gave four star though carrier recogn signatur phone wound buy friendli phone phone work bill system would automat charg smartphon extra bill sinc recogn signatur give militari reus',
#  'sim card dose read point sell tablet phone work',
#  'item worth money paid cant find put memori card screen clear blur item suck',
#  'good phone',
#  'tablet realli look sim card work sd card never read charger cord broke purchas anoth realli upset product realli surpris want tablet would thing',
#  'charg batteri screen wave interfer point would use tablet charg return tablet',
#  'littl ok use straighttalk unlimit plan g phone g sim lot chines app remov view angl screen best howev look realli sharp straight excel qualiti pictur video netflix poor camera text network reach friend android kitti kat use googl app voic search excel deciph worn grave southern accent everi time work well great phone intern travel pop european sim extra slot busi phablet better camera would steal batteri last day use phone surf use wi fi continu need recharg often go kept use',
#  'tablet work month give troubl connect wifi play store access suck',
#  'realli nice daughter use everyday almost year still go strong love',
#  'good',
#  'thank best suppli',
#  'googl play even though pictur descript say contact e passion wors useless kept tell stupid stuff like instal googl play non exist app market obviou understand much english',
#  'upset tablet work send back replac',
#  'excel',
#  'great phablet gener use',
#  'like languag mandarin hk also cannot downland app android store',
#  'friend brought work order amazon work togeth oversea live johannesburg got home test phone microphon doesnt work hear one hear im stuck would get ut back texa unhappi product',
#  'friend brought work order amazon work togeth oversea live johannesburg got home test phone microphon doesnt work hear one hear im stuck would get ut back texa unhappi product',
#  'arriv broken forgot send back',
#  'phone worth money plastic flimsi phone hardli work tri return mine wast money',
#  'second sim card use activ phone contact compani still respons current research matter earli rate caus phone two week',
#  'littl phone great compact easi use love michelleheraud',
#  'littl phone great compact easi use love michelleheraud',
#  'littl phone great compact easi use love michelleheraud',
#  'hate send back keep blink want refund back',
#  'buy work good price would extrem durabl averag person hvac break lot holster fault',
#  'wonder got son tend break extra without go hassl order thank rate star',
#  'last longer oem',
#  'crear product fast arriv',
#  'work great',
#  'look like origin believ origin whole lot cheaper',
#  'work nice price bought mani',
#  'bought father littl month ago abl give today put phone holster phone held secur still origin otterbox holster compar phone fit snugli holster basic otterbox piec hold phone place replac holster allow phone slip bare bump would love return window pass',
#  'great',
#  'great valu one use otterbox defend',
#  'great buy servic',
#  'work great',
#  'bought pack still first one seem work well broke hold phone without bulk leather flip case',
#  'thick old one',
#  'purchas pack week back broke third one today brittl slightli smaller need fit defend case last otterbox clip last year final broke would recommend item',
#  'clip break easili ok price',
#  'fit advertis',
#  'like number review break holster everi month otterbox good warranti honestli pain get lot knock off main competitor even wors name mention like otterbox use three phone issu holster breakag decid give gener holster tri one month use two back up far issu appear look work well otterbox brand fraction cost break three buy three easier faster get replac otterbox even mention competitor will take chanc go gener good choic juli month later still use first one look like new work perfectli treat gentli realli happi thu far',
#  'order everi month husband phone brake clip these good price three help keep order everi month fit case well clip belt without problem',
#  '',
#  'good product describ',
#  'seem origin much lower price',
#  'husband break otter box belt clip everi month great get pack fit perfect otter box',
#  'seem work fine',
#  'look feel fit like origin press china instead mexico complaint',
#  'clearli knock first one snap week coupl buck unexpect',
#  'anybodi otterbox know belt clip break frequent clip last long brand name much better price fast shipment',
#  'got two belt clip one function properli',
#  'download music applic come unlock accessori well good price amazin seller',
#  'hey phone charg insul film torn idk use understand',
#  'phone power sent jamaica wi return receiv back',
#  'good',
#  'phone alright though come sd card need go instal app',
#  'good price',
#  'sim card slide way slot open phone retriev chip',
#  'phone memori small work errat work anymor recommend buy phone',
#  'bought son got connect thru consum cellular add line work fine includ function given problem yet year far buy',
#  'good',
#  'like design cost worth bought famili member far complaint',
#  'work network',
#  'ok phone buy someon',
#  'work short batteri life',
#  'good tank',
#  'nice phone buy use travel outsid us love good smartphon price',
#  'read review fact go say fake five star review bought phone phone absolut terribl secur sticker broken got product contact seller said okay long phone work still abl use data phone use call text also afraid phone ear burn realli hot radiat heat cheapli made touch screen fickl unrespons zero phone storag app bottom line wish would spent littl money bought differ phone',
#  'first thought charg small plastic strip batteri need remov remov phone work great',
#  'phone horribl speaker work right app never buy phone never recommend anyon thing nice cheap could give phone star would',
#  'got could test android app work well issu softwar hardwar limit memori forc buy sd card realli use still worth price paid',
#  'wife love work great easi use',
#  'phone work well phone call small intern memori could one app download could send reciev mm batteri portal broke own momth also reset often wifi slow go sea need make call good phone everyday use',
#  'excel phono low cost',
#  'receiv phone time packag well came charger headphon plu howev rate three phone feel like toy phone light weight almost feel like break inch drop liter also display hard read bought oldest two children verizon pre paid phone amazon octob ye awesom phone go howev due qualiti im go give youngest child look small cheap phone work though think phone overpr even',
#  'excel',
#  'great expect',
#  'love much',
#  'muy bueno',
#  'mom love screen crack month later lay purs',
#  'got took forev turn megabyt intern storag even gig sd card qualiti extrem terribl buy unless want wast money junk',
#  'horribl horribl phone recept keep download program buy',
#  'good',
#  'didnt new phone',
#  'small phone compat us servic nice color amaz storag',
#  'work nevera bad',
#  'slow slow slow home network nokia alreadi load weather channel local forecast phone still load restat review terribl view angl despit adjust sensit screen final th tap screen respond request seem hit miss phone usa phone standard probabl return altho great look phone make receiv call would pretti much paper weight wonder star review sound mysteri similar languag style choic word phrase make wonder fact valid perfect exampl get pay much updat august impress custom servic compani receiv nicest e mail regard comment ask anyth could make purchas right compani actual personnel custom servic read review purchas appar e mail back forth turn newer model probabl mind smart phone go buy also suggest updat product inform product woefulli lack tech inform told process happen also updat review star fabul respons custom servic compani fact phone may right someon exact requir phone give benefit doubt base review absolut assur valid honest review purchas kudo shawyn compani',
#  'could gave star would aw phone never seller phone usa standard mayb good across sea use',
#  'realli bad liter memori page put stuff would recommend unless wanna call take good pic',
#  'disappoint screen love purpl flower see want return back phone feel like use color either n also hard time open insert sim',
#  'phone work fine would like extens instruct far find protect cover',
#  'gave phone birthday gift friend seem happi far',
#  'fan touchscreen phone trust nokia e gave ghost make transit phone meet need noth fanci nice size fit perfectli palm final download whatsapp sibl friend teas end smartphon download app realli spec husband techi took look descript confirm would perfect need day far good updat review anyth chang love purpl color',
#  'phone seven day impress setup simpl screen qualiti great processor fast',
#  'extrem fast good look phone excel storag option great screen clariti',
#  'recommend charg week use',
#  'phone meet minimum standard network good receiv g phone satisfi desir purchas',
#  'never got thing turn would take charg low expect consid price want use back run credit card use squar go work return',
#  'bought phone gift reciev phone work pay return cellphon venezuela usa',
#  'work',
#  'simpl enough plenti function',
#  'excel',
#  'product expens qualiti might worth mayb better ad littl extra get use second third gener galaxi iphon definit last longer regret purchas screen went south week use also screen qualiti ideal',
#  'better expect',
#  'say mobil compat howev sim card insert connect would say sim connect network great price noth use phone wi fi avail call servic away home phone cute need app home',
#  'excel',
#  'bad',
#  'cheap phone thought gave tri guess want good low intern memori lot ad thrown also freez quit bit guess good want use talk travel dual sim card slot',
#  'like phone horribl phone',
#  'slow regret buy suggest differ phone',
#  'excel',
#  'hate phone week later buy anoth one slow storag poor wast money never',
#  'bad',
#  'good get heat talk five minut',
#  'piec crap',
#  'took phone mexico surf web made call voip regular phone heroic camera bad either',
#  'bueno',
#  'excel thank u',
#  'great phone easi use price realli good',
#  'phone come sim card work',
#  'best phone made work temporari',
#  'good basic smart phone',
#  'satisfi product valu money',
#  'hope decent phone price gift niec everi time use phone repeatedli drop call prepaid account area strong signal wasne carrier buy anoth phone',
#  'wonder phone absolut met expect took west indi work perfectli',
#  'phone turn batteri dead charg',
#  'phone turn even charg phone hour hope joke',
#  'excel',
#  'first thought charg small plastic strip batteri need remov remov phone work great',
#  'download music applic come unlock accessori well good price amazin seller',
#  'hey phone charg insul film torn idk use understand',
#  'phone power sent jamaica wi return receiv back',
#  'good',
#  'phone alright though come sd card need go instal app',
#  'good price',
#  'sim card slide way slot open phone retriev chip',
#  'phone memori small work errat work anymor recommend buy phone',
#  'bought son got connect thru consum cellular add line work fine includ function given problem yet year far buy',
#  'phone horribl speaker work right app never buy phone never recommend anyon thing nice cheap could give phone star would',
#  'got could test android app work well issu softwar hardwar limit memori forc buy sd card realli use still worth price paid',
#  'wife love work great easi use',
#  'phone work well phone call small intern memori could one app download could send reciev mm batteri portal broke own momth also reset often wifi slow go sea need make call good phone everyday use',
#  'excel phono low cost',
#  'receiv phone time packag well came charger headphon plu howev rate three phone feel like toy phone light weight almost feel like break inch drop liter also display hard read bought oldest two children verizon pre paid phone amazon octob ye awesom phone go howev due qualiti im go give youngest child look small cheap phone work though think phone overpr even',
#  'excel',
#  'great expect',
#  'suck',
#  'work great luv',
#  'great phone work perfectli oversea great buy love phone',
#  'excel thank',
#  'end return phone put sim card stop went phone could reach use tini screwdriv take phone apart retriev sim card phone also lack space app updat',
#  'great cheap phone',
#  'fine',
#  'phone last day went dead never came back charg come horribl phone',
#  'excel',
#  'love',
#  'muy bueno',
#  'mom love screen crack month later lay purs',
#  'got took forev turn megabyt intern storag even gig sd card qualiti extrem terribl buy unless want wast money junk',
#  'horribl horribl phone recept keep download program buy',
#  'good',
#  'didnt new phone',
#  'small phone compat us servic nice color amaz storag',
#  'work nevera bad',
#  'wast money cheapest phone ever save sd card download download thing intern hard drive star would give left',
#  'phone good touch screen show good lighter applic theme hd screen certain extent batteri last long time good sound qualiti',
#  'phone look beauti high configur pictur clear well call run fast featur high cost perform short overal condit good suit well',
#  'mobil phone run smooth system good batteri life color classic fashion pixel rel high pictur clear caus like take photo',
#  'phone give good experi pretti appear compact structur conveni oper way simplic design good qualiti attract',
#  'nice color run smooth stabl system audio qualiti voic good beyond expect',
#  'screen simpl tactil easi brows',
#  'put use soon receiv real good thing match price workmanship fine possess eleg appear human orient design way packag combin concis simplif',
#  'great phone fast deliveri',
#  'could gave star would aw phone never seller phone usa standard mayb good across sea use',
#  'realli bad liter memori page put stuff would recommend unless wanna call take good pic',
#  'disappoint screen love purpl flower see want return back phone feel like use color either n also hard time open insert sim',
#  'phone work fine would like extens instruct far find protect cover',
#  'gave phone birthday gift friend seem happi far',
# ...
#  'ok best cell phone work ok venezuelan digitel movistar movilnet',
#  'smartphon excel dig littl set chang languag english spanish quick long life batteri recommend googl play le man',
#  'great phone price larg screen brows web easi use speed ok wifi g situat drawback batteri life last hour may need extra batter mobil batteri better check seller make sure phone root carrier neutral got phone pre instal china unicom take time uninstal carrier softwar',
#  'good phone seller say come googleplay q lie bring applic chines',
#  'bought phone work great scari thing speak everyth chines speak english yike husband took phone phone dealer chang languag set buy phone see speak anoth languag simpli take phone dealer top line phone fraction price',
#  'littl visibl light environ like outsid shadow batteri life could better big screen good read text',
#  'great phone',
#  'exelent',
#  'good even write notifi product alreadi reach hand good condit present sever problem one one box phone come without secur seal without adhes inner side compar phone bring bring two one iridesc one bar code problem present greatest one phone adhes problem get charger connect origin lenovo charger brought packag minut maximum accept regist charg light turn stop charg batteri wonder procedur case necessari forward phone direct thank prompt respons problem present say goodby gaudi fermin',
#  'excel',
#  'ring good',
#  'excel',
#  'aw definet',
#  'fine',
#  'muy bueno',
#  'excelent',
#  'cell phone arriv sever day expect mobil work excel fast big screen look good problem camera night good price think good mobil',
#  'cel mani flaw remain stuck restart falla hedg son came mani esta tel bad comput oper',
#  'reach tlf',
#  'ye item select',
#  'love good product best servic',
#  'excel',
#  'work excel argentina good qualiti',
#  'phone g even add say g internet run super slow second sim card work properli shame caus nice phone detail use call text wifi ok',
#  'excelent muy bueno',
#  'excelent muy bueno',
#  'date phone android flaw buck unbeat qualiti beauti design easili pass phone cost lenovo recogniz brand trust durabl name cheap phone',
#  'excelent',
#  'excel',
#  'mobil good small detail make uncomfort use button activ screen awkward posit otherwis sastifecho',
#  'okay',
#  'featur amaz clean neat',
#  'great phone easi access applic work perfectli venezuela recommend',
#  'congratulect ok',
#  'uff love smartphon realli work venezuelan servic',
#  'like later gave friend plan buy anoth one return home usa',
#  'nice phone game work well straight talk',
#  'excel product came good stuff pen drive case screen protector',
#  'five star excel',
#  'left side screen vertic area inch touch respons way chines softwar retard hard correct remov despit root superus app preinstal use multipl app perform realli start struggl support otg youtub app becom glitchi unknown reason pro larg screen decent resolut larg batteri fm radio nice back temp phone look flash rom custom instal futur updat complet',
#  'like phone nice camera',
#  'odlican telefon usluga',
#  'phone good phone yeah right g slow without use wifi',
#  'good',
#  'great thank number respons came good',
#  'excelent',
#  'ask peopl question amazon whether would work digi mobil movistar everyon said would requir sim adapt review anyon give phone star never own premium smartphon review compar samsung galaxi touchscreen factori provid screen protector sometim unrespons sometim freez hold touch screen button time phone realiz touch less half time button respond take screen protector work marvel risk damag screen network movistar digimobil pay go plan got sim bought samsung galaxi young use major issu asid phone size young whatsapp work fine could send text make phone call whatsapp mobil network wifi sim lenovo allow transmit whatsapp unless connect wifi addit internet googl play access without wifi phone return',
#  'useless chines',
#  'good phone price',
#  'excel',
#  'lenovo pone pone kid toy plea remov market thank rate',
#  'chines menu hard oper',
#  'disappoint wast money much hassl return',
#  'excel fash',
#  'excel',
#  'good buena',
#  'excelent producto',
#  'excel',
#  'awesom bought one husband one',
#  'phone quit big perfect dad mostli use phone play candi crush send text total love fast perfect deal price',
#  'excel',
#  'buen celular',
#  'good phone sent defect sound call use headphon ideal take repair',
#  'phone work',
#  'excelent',
#  'good mobil',
#  'nice product reason ship speed languag set somewhat challeng initi languag greek help googl translat chang english eventu',
#  'amaz phone cabl case includ also screen pritector amaz phone',
#  'excel',
#  'excel meet requir request',
#  'good',
#  'good basic chines phone googl play return product within hour sinc go deliv would suggest buy phone',
#  'total disappoint team come chines english describ spanish worst longer android googl instal play apk download permit run app googl inc una total decepci n el equipo vien solo en chino e ingl en espa ol como describ lo peor es que tien android ya que tien instalado googl play al bajarlo como apk permit ejecutar la app ni ninguna otra de googl inc',
#  'found featur work properli without glitch mine came googl play includ work fine oper system proper english found calendar applic chines charact use applic disabl usual android phone came mani applic cannot uninstal disabl use disappear icon screen big nice phone still fit shirt pocket even case also bought amazon use sim miami anoth one costa rica travel frequent work fine first time phone came without setup manual newbi may download one internet',
#  'everyth work like describ satisfi product far surpris problem would recommend anyon',
#  'product repres everyth brand suggest good qualiti product well packag accessori part good overal condit new mind appear imag compani grate recommend product',
#  'good perform touchscreen display okgoogl play store app work without problem make sure oper support g phone',
#  'good smartphon prize cpu realli fast big screen let enjoy app great size',
#  'tri sever phone year includ two nexu galaxi note none approach one fluid easi use everyth work describ screen seem larg paper guarante feel start use receiv phone time seller great job playstor preinstal take much time come download neflix internet directli instal playstor start work even without playstor preinstal still instal app playstor webpag restrict',
#  'excel price qualiti ratio although oper system modifi version lenovo hope soon avail version cosinada versatil',
#  'first android phone iphon till start show age instead spend well iphon c decid tri android nexu like lenovo spec look feedback convinc tri especi sinc cost littl amazon includ ship yeah wait deliv china take long caveat like gb memori storag microsd card swap gb card flash cleaner version lenovo iter android realli enjoy power respons mediatek processor gb ram seem ampl gener use watch video decent game handl well also like batteri life stop buy extra batteri batteri charger sinc swap batteri make never realli need sit charg unless want bottom line know way around android even novic like gonna realli like phone keep expect equal price pay',
#  'order friday lightinthebox home store deliv dhl next tuesday impress good mobil bright display singl con contain china english softwear version need upgrad even chose english version sometim see chines letter softwear chang process took approxim minut good mobil price less',
#  'thank gift sent packag screen protectorgood perform touchscreen display okgoogl play store app work without problem perfect usabl smartphon tablet combin devic',
#  'good perform touchscreen display ok quit big good seniorsgoogl play store app work without problem thing worri chines languag boot menu chines messag menu entri show seldom deeper set use germani local languag set gui work fine declar root pseudo serious rootabl son got minut web search perfect usabl smartphon tablet combin devic bought lightonlin',
#  'lenovo chines phone android oper system phone chines cant instal googl play get around root phone instal custom rom english henc bought phone root googl play case phone program chines everyth written chines charact googl play function standard oper system phone seller use fals advertis product descript bad man make cri phone googl play pre instal flash root phone instal',
#  'good smart phone first devic fast lag softwar nice batteri life accept daili use feel good hand camera realli expect cost great deal quad core gb ram big screen bad camera nice finish style',
#  'thank gift sent packag screen protector case nice thank',
#  'nice product price',
#  'happi fulfil expect love phone phone good price recommend',
#  'excel',
#  'good phone excel hardwar good perform high compat intern oper venezuela',
#  'bought brother love screen size resolut great',
#  'sinc receiv phone turn work bad phone',
#  'phone fantast better thought bad thing chines venezuela chang languag spanish',
#  'nice cell need qualiti control recogn sim card port think last time buy amazon cell fork success',
#  'excelent',
#  'excel',
#  'good cellphon',
#  'would stay return',
#  'excel choic cellphon',
#  'phone bag open box ok',
#  'excel',
#  'super fast ship love seller happi smartphon thank',
#  'receiv phone yesterday root root phone nice fast far keep guy post anyth new',
#  'work well great valu',
#  'fine',
#  'good',
#  'lo vendi',
#  'phone made china plan use phone outsid china buy phone configur work china even time clock phone set china time zone cannot chang phone accept chang cannot instal new app make chang pre instal app number chines junk app pre instal phone often give messag chines languag also crash frequent get sever error messag need reboot frequent chang made get lost time reboot text messag contact even disappear randomli batteri drain quickli stay away piec junk live china',
#  'love unfortun accompani english manual guid',
#  'hurt week later provid defect good',
#  'like good seller nice cellphon use phone use philippin noth problem',
#  'todo perfecto',
#  'excelent',
#  'think repair phone give phone work anyth turn hate worst phone ever buy plastic aluminium stole',
#  'phone light fast howev allow chang languag set english chines rout gool play store lenovo store chines buy amazon tri help help',
#  'one bought dealextrem work realli well mani drop rememb main reason buy sinc quit clumsi hold cell secondli think cel quit fast price even though pictur qualiti great pair high def camera point click ok hope would come memori could complain sinc price seem right',
#  'excelent',
#  'return broken screen',
#  'exel',
#  'excelent',
#  'good phone acord cost',
#  'ok',
#  'best price valu benefit deal chines lenovo built app english lenovo great brand',
#  'excelent',
#  'excel product arriv good condit good qualiti',
#  'item return',
#  'ver good',
#  'excel product',
#  'excelent',
#  'time excel',
#  'good excel equip',
#  'excel',
#  'look great instruct chines speak english difficult learn new tap techniqu light tap sever time work screen went black week request return slip day three still wait',
#  'excel',
#  'decent phone price realli complain serv purpos',
#  'good thank',
#  '',
#  'know good phone month yet know good bad survis',
#  'use phone six month charg point stop work languag chines wast money time',
#  'nice item',
#  'well cellphon excel fast problem lenguag mix exampl spanish app lenguag appear un chines uniqu one problem happi',
#  'love',
#  'excel',
#  'excel',
#  'latest review gone live amazon million shopper amazon appreci time took write experi item review statsno profil imag review written review rank would like add review alway edit product imagerca unlock dual sim star star five star april deivi rosstaverifi purchas review rca unlock dual sim mp camera android ghz white wireless phone accessori satisfi purchas expect thank much recommendse review sitereview purchas',
#  'scam becar',
#  'excel price',
#  'absolut recommend product exlus asian market lenovo provid technic servic worldwid smartphon interfac pc chines languag recomend consum advanc knowledg program chines cours p item technic issu charger slot know deal custom actual prefer even write never',
#  'excel',
#  'love',
#  'great phone price']

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv=CountVectorizer(max_features=20000,min_df=5,ngram_range=(1,2))

# %%
X=cv.fit_transform(df['Reviews'])

# %%
X.shape
# Out:
# (382015, 20000)

# %%
y=df['sentiment'].values

# %%
y.shape
# Out:
# (382015,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
X_train
# Out:
# <305612x20000 sparse matrix of type '<class 'numpy.int64'>'
# 	with 13848947 stored elements in Compressed Sparse Row format>

# %%
from keras.models import Sequential
